# %% [markdown]
# # Ex. No: 03
# ## Histogram Equalization Using OpenCV (Grayscale & Color Images)
#
# **Name :** ASTLE JOE A S    **Reg. No :** 212224240019    **Slot No :** T2-J6

# %% [markdown]
# ### Write a Python program using OpenCV to perform histogram equalization on the given grayscale image **"parrot.jpg"**.
#
# The program should:
#
# - Import the required libraries (**OpenCV, NumPy, Matplotlib**).
# - Read the image **"parrot.jpg"** in **grayscale** format.
# - Display the grayscale image and plot its histogram.
# - Perform **histogram equalization** on the grayscale image using `cv2.equalizeHist()` to enhance its contrast.
# - Using Matplotlib, display the following in a **2 × 2 grid layout**:
#   - Original Grayscale Image
#   - Histogram of Original Image
#   - Enhanced (Equalized) Image
#   - Histogram of Enhanced Image

# %%
# Import required libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the image in grayscale format
img = cv2.imread('parrot.jpg', cv2.IMREAD_GRAYSCALE)

# %%
# Display the grayscale image.
plt.imshow(img, cmap='gray')
plt.title('Grey Scale Image')
plt.show()

# %%
assert np.array_equal(img, cv2.imread('parrot.jpg', cv2.IMREAD_GRAYSCALE))

# %%
# Plot the histogram of the grayscale image
plt.hist(img.ravel(), 256, [0, 256])
plt.title("Histogram of Grayscale Image")
plt.xlabel("Pixel Intensity")
plt.ylabel("Number of Pixels")
plt.show()
# Out:
# C:\Users\astle\AppData\Local\Temp\ipykernel_1360\4272015808.py:2: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(img.ravel(), 256, [0, 256])

# %%
# Perform histogram equalization

equalized_img = cv2.equalizeHist(img)

# %%
# Display [1] the Original Image (Gray Image) and its Histogram, and [2] the Enhanced Image and its Histogram using a 2×2 layout in Matplotlib.

# Create 2×2 layout
plt.figure(figsize=(10, 8))

# Original Grayscale Image
plt.subplot(2, 2, 1)
plt.imshow(img, cmap='gray')
plt.title("Original Grayscale Image")
plt.axis('off')

# Histogram of Original Image
plt.subplot(2, 2, 2)
plt.hist(img.ravel(), 256, [0, 256])
plt.title("Histogram of Original Image")
plt.xlabel("Pixel Intensity")
plt.ylabel("Number of Pixels")

# Enhanced (Equalized) Image
plt.subplot(2, 2, 3)
plt.imshow(equalized_img, cmap='gray')
plt.title("Enhanced Image")
plt.axis('off')

# Histogram of Enhanced Image
plt.subplot(2, 2, 4)
plt.hist(equalized_img.ravel(), 256, [0, 256])
plt.title("Histogram of Enhanced Image")
plt.xlabel("Pixel Intensity")
plt.ylabel("Number of Pixels")

# Adjust layout
plt.tight_layout()

# Show all plots
plt.show()
# Out:
# C:\Users\astle\AppData\Local\Temp\ipykernel_1360\990285120.py:14: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(img.ravel(), 256, [0, 256])
# C:\Users\astle\AppData\Local\Temp\ipykernel_1360\990285120.py:27: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(equalized_img.ravel(), 256, [0, 256])

# %% [markdown]
# ### Write a Python program using OpenCV to perform color image enhancement through histogram equalization in the HSV color space on the given image **"parrot.jpg"**.
#
# The program should:
#
# - Import the required libraries (**OpenCV, NumPy, Matplotlib**).
# - Read the color image **"parrot.jpg"**.
# - Plot the **histogram of the original color image** (use the **B, G, and R** channels).
# - Convert the image from **BGR to HSV** color space.
# - Apply **histogram equalization** to one specific channel to improve brightness and contrast using `cv2.equalizeHist()`.
# - Convert the enhanced HSV image back to **BGR** format.
# - Using Matplotlib, display the following in a **2 × 2 grid layout**:
#   - Original Color Image
#   - Histogram of Original Image (BGR channels)
#   - Enhanced Color Image
#   - Histogram of Enhanced Image (BGR channels)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the colorgiven parrot.jpg image.

img = cv2.imread('parrot.jpg', cv2.IMREAD_COLOR)

# %%
# Plot the histogram of colour image
# Plot histogram for B, G, R channels

# Blue channel
plt.hist(img[:, :, 0].ravel(), 256, [0, 256], color='blue', alpha=0.5)

# Green channel
plt.hist(img[:, :, 1].ravel(), 256, [0, 256], color='green', alpha=0.5)

# Red channel
plt.hist(img[:, :, 2].ravel(), 256, [0, 256], color='red', alpha=0.5)

# Add title and labels
plt.title("Histogram of Color Image")
plt.xlabel("Pixel Intensity")
plt.ylabel("Number of Pixels")

# Show histogram
plt.show()
# Out:
# C:\Users\astle\AppData\Local\Temp\ipykernel_1360\2969595596.py:5: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(img[:, :, 0].ravel(), 256, [0, 256], color='blue', alpha=0.5)
# C:\Users\astle\AppData\Local\Temp\ipykernel_1360\2969595596.py:8: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(img[:, :, 1].ravel(), 256, [0, 256], color='green', alpha=0.5)
# C:\Users\astle\AppData\Local\Temp\ipykernel_1360\2969595596.py:11: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(img[:, :, 2].ravel(), 256, [0, 256], color='red', alpha=0.5)

# %%
# Convert to HSV.
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# %%
# Perform histogram equalization
img_hsv[:,:,2] = cv2.equalizeHist(img_hsv[:, :, 2])

# %%
# Convert back to BGR format
img_eq = cv2.cvtColor(img_hsv, cv2.COLOR_HSV2BGR)

# %%
# Display


plt.imshow(img_eq[:,:,::-1]); plt.title('Equalized Image');plt.show()
